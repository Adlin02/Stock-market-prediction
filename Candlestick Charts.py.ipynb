# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.0 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install mplfinance
# Out:
# ...
#   Using cached mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install TA_Lib-*.whl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Requirement 'TA_Lib-*.whl' looks like a filename, but the file does not exist
# ERROR: TA_Lib-*.whl is not a valid wheel filename.
#
# [notice] A new release of pip is available: 23.0 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
stock = yf.Ticker("TATASTEEL.NS")
hist = stock.history(period='12mo')

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-04-24 00:00:00+05:30  103.037050  103.327564  102.020234  103.133888
# 2023-04-25 00:00:00+05:30  103.327568  104.199123  102.891794  103.666512
# 2023-04-26 00:00:00+05:30  103.133888  103.666507  102.504431  103.472824
# 2023-04-27 00:00:00+05:30  102.940214  104.441219  102.940214  104.247543
# 2023-04-28 00:00:00+05:30  104.392802  105.070675  103.908606  104.538055
# ...                               ...         ...         ...         ...
# 2024-04-15 00:00:00+05:30  161.800003  164.699997  158.600006  160.850006
# 2024-04-16 00:00:00+05:30  160.850006  162.449997  159.000000  160.050003
# 2024-04-18 00:00:00+05:30  160.899994  164.000000  159.149994  160.050003
# 2024-04-19 00:00:00+05:30  160.000000  162.500000  157.300003  162.100006
# 2024-04-22 00:00:00+05:30  163.800003  164.699997  161.500000  161.850006
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
import mplfinance as mpf
import matplotlib.pyplot as plt

mpf.plot(hist, type='candle', title="GOOGLE Candlestick Chart (Daily)", style='yahoo', figscale = 2.0, figratio = (1, 0.3))

# %%
weekly_data = hist['Close'].resample('W').ohlc()

mpf.plot(weekly_data, type='candle', title="TATASTEEL Candlestick Chart (Weekly)", style='yahoo', figscale = 2.0, figratio = (1, 0.3))
